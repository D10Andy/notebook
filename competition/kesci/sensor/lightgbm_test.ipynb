# %%
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
iris=datasets.load_iris()
X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,test_size=0.3)
import numpy as np
train_data=lgb.Dataset(X_train,label=y_train)
validation_data=lgb.Dataset(X_test,label=y_test)
params={
    'learning_rate':0.1,
    'lambda_l1':0.1,
    'lambda_l2':0.2,
    'max_depth':4,
    'objective':'multiclass',
    'num_class':3,  #lightgbm.basic.LightGBMError: b‘Number of classes should be specified and greater than 1 for multiclass training‘
}
clf=lgb.train(params,train_data,valid_sets=[validation_data])
from sklearn.metrics import roc_auc_score,accuracy_score
y_pred=clf.predict(X_test)
y_pred=[list(x).index(max(x)) for x in y_pred]
print(y_pred)
print(accuracy_score(y_test,y_pred))
# Out:
# [1]	valid_0's multi_logloss: 0.975313
# [2]	valid_0's multi_logloss: 0.871948
# [3]	valid_0's multi_logloss: 0.784272
# [4]	valid_0's multi_logloss: 0.709039
# [5]	valid_0's multi_logloss: 0.64061
# [6]	valid_0's multi_logloss: 0.583513
# [7]	valid_0's multi_logloss: 0.531207
# [8]	valid_0's multi_logloss: 0.484323
# [9]	valid_0's multi_logloss: 0.445142
# [10]	valid_0's multi_logloss: 0.407942
# [11]	valid_0's multi_logloss: 0.376778
# [12]	valid_0's multi_logloss: 0.348516
# [13]	valid_0's multi_logloss: 0.321427
# [14]	valid_0's multi_logloss: 0.299683
# [15]	valid_0's multi_logloss: 0.279393
# [16]	valid_0's multi_logloss: 0.260844
# [17]	valid_0's multi_logloss: 0.242812
# [18]	valid_0's multi_logloss: 0.228009
# [19]	valid_0's multi_logloss: 0.213828
# [20]	valid_0's multi_logloss: 0.201038
# [21]	valid_0's multi_logloss: 0.189587
# [22]	valid_0's multi_logloss: 0.179642
# [23]	valid_0's multi_logloss: 0.170342
# [24]	valid_0's multi_logloss: 0.16269
# [25]	valid_0's multi_logloss: 0.153622
# [26]	valid_0's multi_logloss: 0.146686
# [27]	valid_0's multi_logloss: 0.13968
# [28]	valid_0's multi_logloss: 0.13295
# [29]	valid_0's multi_logloss: 0.126337
# [30]	valid_0's multi_logloss: 0.120956
# [31]	valid_0's multi_logloss: 0.116425
# [32]	valid_0's multi_logloss: 0.111825
# [33]	valid_0's multi_logloss: 0.107519
# [34]	valid_0's multi_logloss: 0.103327
# [35]	valid_0's multi_logloss: 0.0996451
# [36]	valid_0's multi_logloss: 0.0961311
# [37]	valid_0's multi_logloss: 0.0929038
# [38]	valid_0's multi_logloss: 0.0897955
# [39]	valid_0's multi_logloss: 0.0869494
# [40]	valid_0's multi_logloss: 0.0843659
# [41]	valid_0's multi_logloss: 0.0820198
# [42]	valid_0's multi_logloss: 0.0798392
# [43]	valid_0's multi_logloss: 0.0777308
# [44]	valid_0's multi_logloss: 0.0760455
# [45]	valid_0's multi_logloss: 0.0746338
# [46]	valid_0's multi_logloss: 0.0729271
# [47]	valid_0's multi_logloss: 0.0714849
# [48]	valid_0's multi_logloss: 0.0704356
# [49]	valid_0's multi_logloss: 0.0688017
# [50]	valid_0's multi_logloss: 0.067813
# [51]	valid_0's multi_logloss: 0.0664385
# [52]	valid_0's multi_logloss: 0.0660542
# [53]	valid_0's multi_logloss: 0.064836
# [54]	valid_0's multi_logloss: 0.0641954
# [55]	valid_0's multi_logloss: 0.0637393
# [56]	valid_0's multi_logloss: 0.063141
# [57]	valid_0's multi_logloss: 0.0627701
# [58]	valid_0's multi_logloss: 0.0617706
# [59]	valid_0's multi_logloss: 0.061802
# [60]	valid_0's multi_logloss: 0.0615182
# [61]	valid_0's multi_logloss: 0.0609105
# [62]	valid_0's multi_logloss: 0.0608479
# [63]	valid_0's multi_logloss: 0.0603813
# [64]	valid_0's multi_logloss: 0.0602438
# [65]	valid_0's multi_logloss: 0.0601128
# [66]	valid_0's multi_logloss: 0.0600194
# [67]	valid_0's multi_logloss: 0.0596886
# [68]	valid_0's multi_logloss: 0.059587
# [69]	valid_0's multi_logloss: 0.0592301
# [70]	valid_0's multi_logloss: 0.059269
# [71]	valid_0's multi_logloss: 0.0594182
# [72]	valid_0's multi_logloss: 0.059117
# [73]	valid_0's multi_logloss: 0.0592137
# [74]	valid_0's multi_logloss: 0.0593645
# [75]	valid_0's multi_logloss: 0.0592369
# [76]	valid_0's multi_logloss: 0.0590031
# [77]	valid_0's multi_logloss: 0.0591887
# [78]	valid_0's multi_logloss: 0.0592458
# [79]	valid_0's multi_logloss: 0.059188
# [80]	valid_0's multi_logloss: 0.0596835
# [81]	valid_0's multi_logloss: 0.0592432
# [82]	valid_0's multi_logloss: 0.0594094
# [83]	valid_0's multi_logloss: 0.0590937
# [84]	valid_0's multi_logloss: 0.0593419
# [85]	valid_0's multi_logloss: 0.0591403
# [86]	valid_0's multi_logloss: 0.0593591
# [87]	valid_0's multi_logloss: 0.0592139
# [88]	valid_0's multi_logloss: 0.0589233
# [89]	valid_0's multi_logloss: 0.0594707
# [90]	valid_0's multi_logloss: 0.0594748
# [91]	valid_0's multi_logloss: 0.0591064
# [92]	valid_0's multi_logloss: 0.0596662
# [93]	valid_0's multi_logloss: 0.059875
# [94]	valid_0's multi_logloss: 0.0601401
# [95]	valid_0's multi_logloss: 0.0606272
# [96]	valid_0's multi_logloss: 0.0605431
# [97]	valid_0's multi_logloss: 0.0611302
# [98]	valid_0's multi_logloss: 0.0610064
# [99]	valid_0's multi_logloss: 0.0613528
# [100]	valid_0's multi_logloss: 0.0615846
# [0, 2, 0, 1, 2, 2, 1, 1, 0, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2, 2, 1, 0, 1, 0, 0, 0, 0, 2, 1, 1, 0, 1, 0, 2, 2, 0, 1, 2, 2, 0, 1, 1, 2, 2, 0]
# 0.9555555555555556

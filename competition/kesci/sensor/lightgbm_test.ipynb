# %%
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
iris=datasets.load_iris()
X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,test_size=0.3)
import numpy as np
train_data=lgb.Dataset(X_train,label=y_train)
validation_data=lgb.Dataset(X_test,label=y_test)
params={
    'learning_rate':0.1,
    'lambda_l1':0.1,
    'lambda_l2':0.2,
    'max_depth':4,
    'objective':'multiclass',
    'num_class':3,  #lightgbm.basic.LightGBMError: b‘Number of classes should be specified and greater than 1 for multiclass training‘
}
clf=lgb.train(params,train_data,valid_sets=[validation_data])
from sklearn.metrics import roc_auc_score,accuracy_score
y_pred=clf.predict(X_test)
y_pred=[list(x).index(max(x)) for x in y_pred]
print(y_pred)
print(accuracy_score(y_test,y_pred))
# Out:
# [1]	valid_0's multi_logloss: 0.994876
# [2]	valid_0's multi_logloss: 0.897229
# [3]	valid_0's multi_logloss: 0.815307
# [4]	valid_0's multi_logloss: 0.74587
# [5]	valid_0's multi_logloss: 0.685955
# [6]	valid_0's multi_logloss: 0.634353
# [7]	valid_0's multi_logloss: 0.590029
# [8]	valid_0's multi_logloss: 0.551284
# [9]	valid_0's multi_logloss: 0.517689
# [10]	valid_0's multi_logloss: 0.488475
# [11]	valid_0's multi_logloss: 0.463099
# [12]	valid_0's multi_logloss: 0.441023
# [13]	valid_0's multi_logloss: 0.421863
# [14]	valid_0's multi_logloss: 0.400478
# [15]	valid_0's multi_logloss: 0.380355
# [16]	valid_0's multi_logloss: 0.357984
# [17]	valid_0's multi_logloss: 0.344225
# [18]	valid_0's multi_logloss: 0.331031
# [19]	valid_0's multi_logloss: 0.319954
# [20]	valid_0's multi_logloss: 0.305951
# [21]	valid_0's multi_logloss: 0.297075
# [22]	valid_0's multi_logloss: 0.288161
# [23]	valid_0's multi_logloss: 0.281002
# [24]	valid_0's multi_logloss: 0.274057
# [25]	valid_0's multi_logloss: 0.268207
# [26]	valid_0's multi_logloss: 0.262032
# [27]	valid_0's multi_logloss: 0.257758
# [28]	valid_0's multi_logloss: 0.251556
# [29]	valid_0's multi_logloss: 0.247531
# [30]	valid_0's multi_logloss: 0.242595
# [31]	valid_0's multi_logloss: 0.239081
# [32]	valid_0's multi_logloss: 0.236537
# [33]	valid_0's multi_logloss: 0.23369
# [34]	valid_0's multi_logloss: 0.229632
# [35]	valid_0's multi_logloss: 0.227422
# [36]	valid_0's multi_logloss: 0.22695
# [37]	valid_0's multi_logloss: 0.22518
# [38]	valid_0's multi_logloss: 0.223728
# [39]	valid_0's multi_logloss: 0.224233
# [40]	valid_0's multi_logloss: 0.223132
# [41]	valid_0's multi_logloss: 0.22337
# [42]	valid_0's multi_logloss: 0.222535
# [43]	valid_0's multi_logloss: 0.222232
# [44]	valid_0's multi_logloss: 0.222101
# [45]	valid_0's multi_logloss: 0.221631
# [46]	valid_0's multi_logloss: 0.222334
# [47]	valid_0's multi_logloss: 0.222028
# [48]	valid_0's multi_logloss: 0.223263
# [49]	valid_0's multi_logloss: 0.222308
# [50]	valid_0's multi_logloss: 0.223263
# [51]	valid_0's multi_logloss: 0.222445
# [52]	valid_0's multi_logloss: 0.222888
# [53]	valid_0's multi_logloss: 0.223416
# [54]	valid_0's multi_logloss: 0.2228
# [55]	valid_0's multi_logloss: 0.224211
# [56]	valid_0's multi_logloss: 0.223703
# [57]	valid_0's multi_logloss: 0.225144
# [58]	valid_0's multi_logloss: 0.224702
# [59]	valid_0's multi_logloss: 0.227045
# [60]	valid_0's multi_logloss: 0.226666
# [61]	valid_0's multi_logloss: 0.227452
# [62]	valid_0's multi_logloss: 0.228204
# [63]	valid_0's multi_logloss: 0.227894
# [64]	valid_0's multi_logloss: 0.227884
# [65]	valid_0's multi_logloss: 0.228739
# [66]	valid_0's multi_logloss: 0.229601
# [67]	valid_0's multi_logloss: 0.229416
# [68]	valid_0's multi_logloss: 0.230909
# [69]	valid_0's multi_logloss: 0.230016
# [70]	valid_0's multi_logloss: 0.23082
# [71]	valid_0's multi_logloss: 0.231733
# [72]	valid_0's multi_logloss: 0.232642
# [73]	valid_0's multi_logloss: 0.231848
# [74]	valid_0's multi_logloss: 0.232747
# [75]	valid_0's multi_logloss: 0.233565
# [76]	valid_0's multi_logloss: 0.232843
# [77]	valid_0's multi_logloss: 0.234984
# [78]	valid_0's multi_logloss: 0.235013
# [79]	valid_0's multi_logloss: 0.23556
# [80]	valid_0's multi_logloss: 0.234888
# [81]	valid_0's multi_logloss: 0.236981
# [82]	valid_0's multi_logloss: 0.237063
# [83]	valid_0's multi_logloss: 0.237291
# [84]	valid_0's multi_logloss: 0.236698
# [85]	valid_0's multi_logloss: 0.238745
# [86]	valid_0's multi_logloss: 0.238825
# [87]	valid_0's multi_logloss: 0.239399
# [88]	valid_0's multi_logloss: 0.238844
# [89]	valid_0's multi_logloss: 0.240851
# [90]	valid_0's multi_logloss: 0.24073
# [91]	valid_0's multi_logloss: 0.240628
# [92]	valid_0's multi_logloss: 0.240834
# [93]	valid_0's multi_logloss: 0.240943
# [94]	valid_0's multi_logloss: 0.242819
# [95]	valid_0's multi_logloss: 0.242734
# [96]	valid_0's multi_logloss: 0.242274
# [97]	valid_0's multi_logloss: 0.244095
# [98]	valid_0's multi_logloss: 0.244014
# [99]	valid_0's multi_logloss: 0.243594
# [100]	valid_0's multi_logloss: 0.245402
# [1, 0, 2, 2, 1, 2, 2, 1, 1, 0, 1, 1, 2, 2, 1, 1, 2, 0, 0, 2, 1, 1, 0, 0, 0, 1, 2, 2, 1, 2, 2, 1, 1, 0, 2, 0, 1, 1, 0, 0, 0, 1, 2, 1, 1]
# 0.9333333333333333
